# %% [markdown]
# Delivery duration prediction - Linear regression

# %% [markdown]
# 1. Problem  statement
# Build a linear regression model to predict the estimated time taken for delivery based on various order and restaurant-related factors.

# %% [markdown]
# 2.Data description
# each record in dataset represents food delivery order and includes:
